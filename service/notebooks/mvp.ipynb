# %% [markdown]
# + Load people.csv → list of dicts
# + Build unweighted NetworkX graph: connect if same school/company or ≥2 shared skills
# + BFS from “You” to a target node → show path

# %% [markdown]
# # MVP — Batch test extraction on 10–20 profiles
#
# This notebook:
# 1. Loads `sample_profiles.jsonl`
# 2. Calls your API `POST /extract-profiles` for each text
# 3. Upserts all results via `POST /ingest-people`
# 4. Shows a preview and the saved `data/people.json`
#
# > Make sure your server is running first:
# ```bash
# uvicorn main:app --reload --port 8000
# ```

# %%
# %pip install -q requests pandas networkx
import json, requests, time, pandas as pd
from pathlib import Path

BASE_URL = "http://127.0.0.1:8000"
SAMPLES = Path("../sample_profiles.jsonl")
OUT = Path("../data/people.json")
#rows = [json.loads(line) for line in SAMPLES.read_text(encoding="utf-8").splitlines() if line.strip()]
rows = json.loads(SAMPLES.read_text(encoding="utf-8"))
print("Loaded samples:", len(rows))

people = []
for r in rows:
    payload = {"text": r["text"]}
    resp = requests.post(f"{BASE_URL}/extract-profiles", json=payload, timeout=60)
    if resp.status_code != 200:
        print("ERR", resp.status_code, resp.text[:200])
        continue
    prof = resp.json()
    prof["_id"] = r["id"]
    people.append(prof)
    time.sleep(0.2)  # gentle

print("Extracted", len(people), "profiles")

# Ingest
resp = requests.post(f"{BASE_URL}/ingest-people", json={"people": people}, timeout=60)
print("Ingest:", resp.status_code, resp.text)

# Preview
df = pd.DataFrame(people)
df.head(400)
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Loaded samples: 130
# Extracted 130 profiles
# Ingest: 200 {"ok":true,"inserted":7,"updated":123,"total":145,"path":"/Users/crishuynh/Documents/Semester 7/DPS970/6ixPathConnect/service/data/people.json"}
#                         name          company  \
# 0                 Travis Liu              RBC
# 1       Kristina Zaporozhets       Scotiabank
# 2               Ngoc Vien Do  York University
# 3              Andrew Nguyen      KPMG Canada
# 4    Tanise Lacasse, CPA, CA      KPMG Canada
# ..                       ...              ...
# 125               Ana Torres        Snowflake
# 126             Oliver Grant         Deloitte
# 127            Nina Kowalski              PwC
# 128         Christopher Bell               EY
# 129              Harsh Patel             KPMG
#
#                                                role                  schools  \
# 0                         Software Engineer in Test     [Seneca Polytechnic]
# 1    Global Analytics and Financial Engineer Intern     [Seneca Polytechnic]
# 2                       Student/Research/Club Roles        [York University]
# 3                                 Software Engineer         [Seneca College]
# 4                                           Partner  [University of Calgary]
# ..                                              ...                      ...
# 125                           Senior Sales Engineer                   [UNAM]
# 126                          Senior Data Consultant                   [UofT]
# 127                           Risk Assurance Senior                    [TMU]
# 128                       Strategy and Transactions               [McMaster]
# 129                              Advisory Associate                   [York]
#
#                                                 skills  \
# 0    [Selenium, Test Automation, Test Engineering, ...
# 1    [C, C++, Applied Research, Communication, Git,...
# 2    [Capital Markets, Communication, Data Analysis...
# 3    [Agile/Scrum, Communication, Git/GitHub, JavaS...
# 4    [Corporate Tax, Canadian Tax, Accounting, Fina...
# ..                                                 ...
# 125        [SQL, Warehousing, Demos, Spanish, English]
# 126               [Python, SQL, ML, Client Management]
# 127                         [ITGC, SOX, Documentation]
# 128    [Valuation, Modeling, PowerPoint, Client Comms]
# 129        [Excel, Financial Analysis, Report Writing]
#
#                                               keywords       seniority  \
# 0    [automation, cloud-native, observability, UI t...           Other
# 1    [analytics, financial engineering, software de...  Student/Intern
# 2    [quantitative finance, data-driven research, c...  Student/Intern
# 3    [software engineering, web development, team c...           Entry
# 4    [corporate tax, asset management, wealth manag...        Manager+
# ..                                                 ...             ...
# 125  [data cloud, LATAM, POC, sales engineering, da...          Senior
# 126  [machine learning, analytics, data consulting,...          Senior
# 127  [risk assurance, IT controls, business process...          Senior
# 128  [M&A, financial analysis, transactions, valuat...          Senior
# 129  [due diligence, mid-market deals, financial ad...             Mid
#
#                                 _id
# 0                        travis_liu
# 1              kristina_z_16412b2a7
# 2            ngoc_vien_do_b13b37244
# 3                       andrewnt219
# 4    tanise_lacasse_cpa_ca_5ab67640
# ..                              ...
# 125                 snowflake_sa_03
# 126                deloitte_data_03
# 127                     pwc_risk_03
# 128                        ey_fa_04
# 129                kpmg_advisory_04
#
# [130 rows x 8 columns]

# %%
# Inspect saved JSON (optional)
from pathlib import Path
p = Path("../data/people.json")
print("people.json exists:", p.exists(), "size:", p.stat().st_size if p.exists() else 0)
print(p.read_text(encoding="utf-8")[:1000])
# Out:
# people.json exists: True size: 63734
# [
#   {
#     "name": "Travis Liu",
#     "company": "RBC",
#     "role": "Software Engineer in Test",
#     "schools": [
#       "Seneca Polytechnic"
#     ],
#     "skills": [
#       "Selenium",
#       "Test Automation",
#       "Test Engineering",
#       "Software Testing",
#       "API Testing",
#       "Web Testing",
#       "CI/CD",
#       "Kubernetes",
#       "OpenShift",
#       "Docker",
#       "Elastic Stack (ELK)",
#       "Dynatrace",
#       "REST APIs",
#       "Python",
#       "JavaScript",
#       "TypeScript",
#       "React.js",
#       "Next.js",
#       "MongoDB",
#       "SQL",
#       "Database Testing",
#       "OAuth",
#       "Jest",
#       "GitHub",
#       "DevOps",
#       "Project Management"
#     ],
#     "keywords": [
#       "automation",
#       "cloud-native",
#       "observability",
#       "UI testing",
#       "API testing"
#     ],
#     "seniority": "Other"
#   },
#   {
#     "name": "Kristina Z",
#     "company": "(Company)",
#     "role": "(Current Role)",
#     "schools": [
#       "(School name)"
#     ],
#     "skills": [
#       "Commu
